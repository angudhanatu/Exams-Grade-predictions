# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
import seaborn as sns

# %% [markdown]
# ## import/load  data sets

# %%
data = pd.read_csv('exams.csv')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %% [markdown]
# ## data investigation

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## view a row

# %%
data['test preparation course']
# Out:
# 0      completed
# 1           none
# 2           none
# 3           none
# 4      completed
#          ...
# 995         none
# 996    completed
# 997         none
# 998         none
# 999    completed
# Name: test preparation course, Length: 1000, dtype: object

# %%
sns.countplot(data, x='gender')
plt.title('GENDER DISTRIBUTION')
plt.savefig("gender.png")
plt.show()

# %%
sns.countplot(data, x='race/ethnicity')
plt.xlabel('RACE')
labels=(data['race/ethnicity'])
group_A_patch = mpatches.Patch(color='blue', label='GROUP A')
group_B_patch = mpatches.Patch(color='red', label='GROUP B')
group_C_patch = mpatches.Patch(color='indigo', label='GROUP C')
group_D_patch = mpatches.Patch(color='orange', label='GROUP D')
group_E_patch = mpatches.Patch(color='green', label='GROUP E')
plt.legend(handles =[group_A_patch, group_B_patch, group_C_patch, group_D_patch, group_E_patch], loc ="upper left")
plt.ylabel('COUNT')
plt.title('TOTAL CLASS DISTRIBUTION BY RACE')
plt.show()

# %% [markdown]
# ## Data Transformation

# %%
data['total score'] =data['math score'] + data['writing score'] + data['reading score']
data['average score']= (data['total score']//3)
data.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
# 5  female        group D                 high school      standard
# 6  female        group A           bachelor's degree      standard
# 7    male        group E                some college      standard
# 8    male        group D                 high school      standard
# 9    male        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          67             67             63
# 1                    none          40             59             55
# ...

# %%
#Using function to solve there is an unresolved error in the code clear_output
#data=  data.drop("total average score", axis=1)
"""def Grades(score):
    for i in range(len(data['average score'])):
        if data['average score'][i]<40:
            return 'Fail'
        elif data['average score'][i] >= 40 and data['average score'][i] < 50:
            return 'Pass'
        elif data['average score'][i] >=50 and data['average score'][i] < 65:
            return "Credit"
        else:
            return "Distinction"
            """
# Out:
# 'def Grades(score):\n    for i in range(len(data[\'average score\'])):\n        if data[\'average score\'][i]<40:\n            return \'Fail\'\n        elif data[\'average score\'][i] >= 40 and data[\'average score\'][i] < 50:\n            return \'Pass\'\n        elif data[\'average score\'][i] >=50 and data[\'average score\'][i] < 65:\n            return "Credit"\n        else:\n            return "Distinction"\n            '

# %%
for i  in range (len(data['average score'])):
    if data['average score'][i]< 40:
        data['average score'][i] ='fail'
    elif data['average score'][i] >= 40 and data['average score'][i] < 50:
        data['average score'][i] = 'Pass'  
    elif data['average score'][i] >= 50 and data['average score'][i]  < 65:
        data['average score'][i] ='Credit'
    else:
        data['average score'][i] ="Distinction"
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10176\2515280539.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['average score'][i] ="Distinction"
# C:\Users\USER\AppData\Local\Temp\ipykernel_10176\2515280539.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Distinction' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data['average score'][i] ="Distinction"

# %%
data1 = data
data1.head(200)
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         1               0                            2      1
# 1         0               3                            5      0
# 2         1               4                            4      0
# 3         1               1                            2      1
# 4         1               4                            0      1
# ..      ...             ...                          ...    ...
# 195       0               3                            5      0
# 196       1               3                            1      1
# 197       1               0                            3      0
# 198       0               1                            0      1
# 199       1               3                            2      1
#
#      test preparation course  math score  reading score  writing score  \
# 0                          0          67             67             63
# ...

# %%
plt.title("count of grade distribution")
plt.ylabel('count of grades')
plt.xlabel('grades')
sns.countplot(data, x='average score', hue='gender') 
plt.show()

# %%
plt.title("count of by lunch type")
plt.ylabel('count of grades')
plt.xlabel('grades')
sns.countplot(data, x='average score', hue='lunch')
plt.show()

# %%
sns.countplot(data, x='average score', hue='parental level of education')
# Out:
# <Axes: xlabel='average score', ylabel='count'>

# %%
sns.countplot(data, x='average score', hue='race/ethnicity')
# Out:
# <Axes: xlabel='average score', ylabel='count'>

# %%
sns.countplot(data, x='average score', hue='gender')
# Out:
# <Axes: xlabel='average score', ylabel='count'>

# %%
sns.countplot(data, x='average score', hue='test preparation course')
# Out:
# <Axes: xlabel='average score', ylabel='count'>

# %%
plt.figure(figsize=(15,15))
sns.catplot(x="parental level of education",y="total score",kind='swarm', data=data)
plt.title('PERFORMANCE BASED ON PARENT LEVEL OF EDU')
plt.xticks()
plt.savefig('edu level.png')
plt.show()
# Out:
# c:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\USER\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\USER\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
cat_columns = data.select_dtypes(include = ['object']).columns
cat_columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'average score'],
#       dtype='object')

# %%
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
LEncoder = LabelEncoder()

# %%
for col in cat_columns:
    data[col] = LEncoder.fit_transform(data[col])
data
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         1               0                            2      1
# 1         0               3                            5      0
# 2         1               4                            4      0
# 3         1               1                            2      1
# 4         1               4                            0      1
# ..      ...             ...                          ...    ...
# 995       1               2                            2      1
# 996       1               3                            0      0
# 997       0               2                            5      0
# 998       0               2                            4      1
# 999       1               0                            4      1
#
#      test preparation course  math score  reading score  writing score  \
# 0                          0          67             67             63
# ...

# %%
data_copy = data.copy()

# %% [markdown]
# ## importing standdard scaler to scale features to have a distributed mean

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
scaled_df = pd.DataFrame(scaled_data,
                         columns=data.columns)

# %%
scaled_df
# Out:
#        gender  race/ethnicity  parental level of education     lunch  \
# 0    0.966559       -1.909268                    -0.314310  0.730577
# 1   -1.034598        0.741266                     1.342861 -1.368782
# 2    0.966559        1.624777                     0.790470 -1.368782
# 3    0.966559       -1.025756                    -0.314310  0.730577
# 4    0.966559        1.624777                    -1.419090  0.730577
# ..        ...             ...                          ...       ...
# 995  0.966559       -0.142245                    -0.314310  0.730577
# 996  0.966559        0.741266                    -1.419090 -1.368782
# 997 -1.034598       -0.142245                     1.342861 -1.368782
# 998 -1.034598       -0.142245                     0.790470  0.730577
# 999  0.966559       -1.909268                     0.790470  0.730577
#
#      test preparation course  math score  reading score  writing score  \
# ...

# %%
correlation_matrix = data.corr()

# %%
pd.DataFrame(scaled_df['average score'].unique())
# Out:
#           0
# 0  0.196639
# 1 -1.218029
# 2  1.611307
# 3  3.025974

# %%
plt.figure(figsize=(8,10))
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
y= scaled_df['average score'] 
x= scaled_df.drop(['average score'], axis=1)
y
# Out:
# 0      0.196639
# 1     -1.218029
# 2     -1.218029
# 3      0.196639
# 4      0.196639
#          ...
# 995    0.196639
# 996    0.196639
# 997    3.025974
# 998    0.196639
# 999   -1.218029
# Name: average score, Length: 1000, dtype: float64

# %%
x
# Out:
#        gender  race/ethnicity  parental level of education     lunch  \
# 0    0.966559       -1.909268                    -0.314310  0.730577
# 1   -1.034598        0.741266                     1.342861 -1.368782
# 2    0.966559        1.624777                     0.790470 -1.368782
# 3    0.966559       -1.025756                    -0.314310  0.730577
# 4    0.966559        1.624777                    -1.419090  0.730577
# ..        ...             ...                          ...       ...
# 995  0.966559       -0.142245                    -0.314310  0.730577
# 996  0.966559        0.741266                    -1.419090 -1.368782
# 997 -1.034598       -0.142245                     1.342861 -1.368782
# 998 -1.034598       -0.142245                     0.790470  0.730577
# 999  0.966559       -1.909268                     0.790470  0.730577
#
#      test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ### split variables into train and test pairs

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=43)

# %%
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# X_train: (700, 9)
# y_train: (700,)
# X_test: (300, 9)
# y_test: (300,)

# %% [markdown]
# # Model BUilding

# %% [markdown]
# # In this section, all the variables were scaled using standard scaler
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()

# %%
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
prediction=rfr.predict(X_test)
predicted = pd.DataFrame(prediction)
predicted
# Out:
#             0
# 0    0.196639
# 1    0.196639
# 2    0.196639
# 3   -1.218029
# 4   -1.218029
# ..        ...
# 295 -1.218029
# 296  0.196639
# 297  0.196639
# 298 -1.218029
# 299  1.611307
#
# [300 rows x 1 columns]

# %%
predicted.value_counts()
# Out:
#  0.196639    104
# -1.218029     77
#  0.196639     32
#  1.611307     26
#  3.025974     10
#  0.196639      8
#  0.196639      6
#  0.196639      5
#  0.196639      5
#  0.196639      4
#  0.196639      3
#  0.196639      3
#  0.196639      3
#  0.196639      3
#  0.196639      2
#  1.625453      2
#  0.196639      1
# -1.104856      1
# -0.256055      1
# -0.256055      1
#  1.639600      1
#  3.011828      1
#  0.196639      1
# Name: count, dtype: int64

# %% [markdown]
# ## import metrics for model accuracy testing

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import ConfusionMatrixDisplay

# %%
print('R2 socre is:',r2_score(y_test, predicted))
print('mean squared error is:', mean_squared_error(y_test,predicted))
print('mean abs error is',mean_absolute_percentage_error(y_test, predicted))
# Out:
# R2 socre is: 0.9937954681639628
# mean squared error is: 0.006216657760949189
# mean abs error is 0.005707558248107779

# %% [markdown]
# # working with unscaled target variable
# # for this section, i didn't scale the target variable. only the dependent variables were scaled using LabelEncoder

# %%
from sklearn.ensemble import RandomForestClassifier
RFC =RandomForestClassifier()

# %%
data_copy
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         1               0                            2      1
# 1         0               3                            5      0
# 2         1               4                            4      0
# 3         1               1                            2      1
# 4         1               4                            0      1
# ..      ...             ...                          ...    ...
# 995       1               2                            2      1
# 996       1               3                            0      0
# 997       0               2                            5      0
# 998       0               2                            4      1
# 999       1               0                            4      1
#
#      test preparation course  math score  reading score  writing score  \
# 0                          0          67             67             63
# ...

# %%
y_copy = data_copy['average score']
x_copy = data_copy.drop(['average score'], axis=1)

# %%
scaled_copy =scaler.fit_transform(x_copy)
pd.DataFrame(scaled_copy,
              columns=x_copy.columns)
# Out:
#        gender  race/ethnicity  parental level of education     lunch  \
# 0    0.966559       -1.909268                    -0.314310  0.730577
# 1   -1.034598        0.741266                     1.342861 -1.368782
# 2    0.966559        1.624777                     0.790470 -1.368782
# 3    0.966559       -1.025756                    -0.314310  0.730577
# 4    0.966559        1.624777                    -1.419090  0.730577
# ..        ...             ...                          ...       ...
# 995  0.966559       -0.142245                    -0.314310  0.730577
# 996  0.966559        0.741266                    -1.419090 -1.368782
# 997 -1.034598       -0.142245                     1.342861 -1.368782
# 998 -1.034598       -0.142245                     0.790470  0.730577
# 999  0.966559       -1.909268                     0.790470  0.730577
#
#      test preparation course  math score  reading score  writing score  \
# ...

# %%
X_Train, X_Test, Y_Train, Y_Test = train_test_split(x_copy, y_copy, test_size=0.2, random_state=43)
print(X_Train.shape)
print(Y_Train.shape)
print(X_Test.shape)
print(Y_Test.shape)
# Out:
# (800, 9)
# (800,)
# (200, 9)
# (200,)

# %%
RFC.fit(X_Train,Y_Train)
# Out:
# RandomForestClassifier()

# %%
RFC_predic =RFC.predict(X_Test)
pd.DataFrame(RFC_predic).value_counts()
# Out:
# 1    122
# 0     51
# 2     21
# 3      6
# Name: count, dtype: int64

# %%
print('r score is: ', r2_score(Y_Test,RFC_predic))
print('accuaracy score is:', accuracy_score(Y_Test,RFC_predic))
print('mean abs error is:', mean_absolute_percentage_error(Y_Test,RFC_predic))
print('mean squared error is: ', mean_squared_error(Y_Test, RFC_predic))
# Out:
# r score is:  1.0
# accuaracy score is: 1.0
# mean abs error is: 0.0
# mean squared error is:  0.0

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTree= DecisionTreeClassifier()

# %%
DTree.fit(X_Train,Y_Train)
# Out:
# DecisionTreeClassifier()

# %%
DTree_predict = DTree.predict(X_Test,)
pd.DataFrame(DTree_predict).value_counts()
# Out:
# 1    122
# 0     51
# 2     21
# 3      6
# Name: count, dtype: int64

# %%
print('r score:', r2_score(Y_Test,DTree_predict))
print('accuracy_score:', accuracy_score(Y_Test,DTree_predict))
print('mean_squared_error', mean_squared_error(Y_Test,DTree_predict))
print('abs error:', mean_absolute_percentage_error(Y_Test,DTree_predict))
# Out:
# r score: 1.0
# accuracy_score: 1.0
# mean_squared_error 0.0
# abs error: 0.0

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neighbor = KNeighborsClassifier()
neighbor.fit(X_Train,Y_Train)
# Out:
# KNeighborsClassifier()

# %%
kneighbor_predictions =pd.DataFrame(neighbor.predict(X_Test))

# %%
kneighbor_predictions.value_counts()
# Out:
# 1    121
# 0     52
# 2     21
# 3      6
# Name: count, dtype: int64

# %%
print('accuracy score:', accuracy_score(Y_Test,kneighbor_predictions))
print('r2 score:', r2_score(Y_Test,kneighbor_predictions))
print('mean squared error:', mean_squared_error(Y_Test,kneighbor_predictions))
print('mean_absolute_percentage_error:', mean_absolute_percentage_error(Y_Test,kneighbor_predictions))
# Out:
# accuracy score: 0.995
# r2 score: 0.9894045348590803
# mean squared error: 0.005
# mean_absolute_percentage_error: 0.005

# %%
scaled_df['prediction'] = kneighbor_predictions

# %%
scaled_df .head(30)
# Out:
#       gender  race/ethnicity  parental level of education     lunch  \
# 0   0.966559       -1.909268                    -0.314310  0.730577
# 1  -1.034598        0.741266                     1.342861 -1.368782
# 2   0.966559        1.624777                     0.790470 -1.368782
# 3   0.966559       -1.025756                    -0.314310  0.730577
# 4   0.966559        1.624777                    -1.419090  0.730577
# 5  -1.034598        0.741266                    -0.314310  0.730577
# 6  -1.034598       -1.909268                    -0.866700  0.730577
# 7   0.966559        1.624777                     0.790470  0.730577
# 8   0.966559        0.741266                    -0.314310  0.730577
# 9   0.966559       -0.142245                     0.790470 -1.368782
# 10  0.966559        1.624777                     0.790470  0.730577
# 11 -1.034598        0.741266                    -0.314310  0.730577
# 12  0.966559        0.741266                    -1.419090  0.730577
# ...

# %%
x_copy['dtr prediction'] = kneighbor_predictions

# %%
x_copy.head(30)
# Out:
#     gender  race/ethnicity  parental level of education  lunch  \
# 0        1               0                            2      1
# 1        0               3                            5      0
# 2        1               4                            4      0
# 3        1               1                            2      1
# 4        1               4                            0      1
# 5        0               3                            2      1
# 6        0               0                            1      1
# 7        1               4                            4      1
# 8        1               3                            2      1
# 9        1               2                            4      0
# 10       1               4                            4      1
# 11       0               3                            2      1
# 12       1               3                            0      1
# 13       1               2                            2      1
# ...

# %%
scaled_df.to_csv('predictedData')
